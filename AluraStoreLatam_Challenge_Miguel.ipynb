# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head(10)
# Out:
#                     Producto Categoría del Producto     Precio  \
# 0          Asistente virtual           Electrónicos   164300.0
# 1            Mesa de comedor                Muebles   192300.0
# 2              Juego de mesa               Juguetes   209600.0
# 3                 Microondas      Electrodomésticos   757500.0
# 4           Silla de oficina                Muebles   335200.0
# 5    Bloques de construcción               Juguetes    24200.0
# 6                Muñeca bebé               Juguetes    44200.0
# 7               Lavavajillas      Electrodomésticos  1189700.0
# 8           Lavadora de ropa      Electrodomésticos  1518200.0
# 9  Carrito de control remoto               Juguetes    75200.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0          6900.0      16/01/2021      Pedro Gomez          Bogotá
# 1          8400.0      18/05/2022  Beatriz Morales        Medellín
# 2         15900.0      15/03/2021   Juan Fernandez       Cartagena
# ...

# %%
tienda2.head(10)
# Out:
#             Producto   Categoría del Producto    Precio  Costo de envío  \
# 0   Silla de oficina                  Muebles  283600.0         15300.0
# 1          Pandereta   Instrumentos musicales   76800.0          2300.0
# 2          Cama king                  Muebles  443300.0         23800.0
# 3          Cama king                  Muebles  906200.0         46400.0
# 4   Silla de oficina                  Muebles  397800.0         19400.0
# 5  Guitarra acústica   Instrumentos musicales  298400.0         16100.0
# 6            Mochila     Deportes y diversión  105900.0          9000.0
# 7        Tablet ABXY             Electrónicos  962600.0         49400.0
# 8    Olla de presión  Artículos para el hogar   82800.0          4800.0
# 9    Cubo mágico 8x8                 Juguetes    9100.0          3800.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# ...

# %%
tienda3.head(10)
# Out:
#                     Producto   Categoría del Producto     Precio  \
# 0           Secadora de ropa        Electrodomésticos  1285100.0
# 1              Mesa de noche                  Muebles   290100.0
# 2          Guitarra acústica   Instrumentos musicales   303500.0
# 3          Balón de voleibol     Deportes y diversión    58800.0
# 4                    Armario                  Muebles   521100.0
# 5                  Impresora             Electrónicos   230700.0
# 6  Carrito de control remoto                 Juguetes    55700.0
# 7           Silla de oficina                  Muebles   464600.0
# 8                  Pandereta   Instrumentos musicales    43500.0
# 9                 Cubertería  Artículos para el hogar    33500.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0         66600.0      17/12/2021    Camila Rivera     Santa Marta
# 1         13600.0      10/02/2021    Maria Alfonso            Cali
# ...

# %%
tienda4.head(10)
# Out:
#                     Producto  Categoría del Producto     Precio  \
# 0               Lavavajillas       Electrodomésticos  1084800.0
# 1                   Cama box                 Muebles   473800.0
# 2        Balón de baloncesto    Deportes y diversión    23700.0
# 3        Modelado predictivo                  Libros    57700.0
# 4                Auriculares            Electrónicos   138900.0
# 5               Refrigerador       Electrodomésticos  1591900.0
# 6         Guitarra eléctrica  Instrumentos musicales   626200.0
# 7  Auriculares con micrófono            Electrónicos    94500.0
# 8                  Iphone 15            Electrónicos  2339000.0
# 9              Mesa de noche                 Muebles   273300.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0         56000.0      11/11/2022    Rafael Acosta          Bogotá
# 1         25400.0      03/01/2020  Izabela de León          Cúcuta
# ...

# %%
tienda['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

tienda_general = pd.concat([tienda, tienda2, tienda3, tienda4])

display(tienda_general.head(10))
# Out:
#                     Producto Categoría del Producto     Precio  \
# 0          Asistente virtual           Electrónicos   164300.0
# 1            Mesa de comedor                Muebles   192300.0
# 2              Juego de mesa               Juguetes   209600.0
# 3                 Microondas      Electrodomésticos   757500.0
# 4           Silla de oficina                Muebles   335200.0
# 5    Bloques de construcción               Juguetes    24200.0
# 6                Muñeca bebé               Juguetes    44200.0
# 7               Lavavajillas      Electrodomésticos  1189700.0
# 8           Lavadora de ropa      Electrodomésticos  1518200.0
# 9  Carrito de control remoto               Juguetes    75200.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0          6900.0      16/01/2021      Pedro Gomez          Bogotá
# 1          8400.0      18/05/2022  Beatriz Morales        Medellín
# 2         15900.0      15/03/2021   Juan Fernandez       Cartagena
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
Ingreso_total = tienda['Precio'].sum()
print(Ingreso_total)
# Out:
# 1150880400.0

# %%
Ingreso_total2 = tienda2['Precio'].sum()
print(Ingreso_total2)
# Out:
# 1116343500.0

# %%
Ingreso_total3 = tienda3['Precio'].sum()
print(Ingreso_total3)
# Out:
# 1098019600.0

# %%
Ingreso_total4 = tienda4['Precio'].sum()
print(Ingreso_total4)
# Out:
# 1038375700.0

# %%
Ingresos_generales = (Ingreso_total + Ingreso_total2 + Ingreso_total3 + Ingreso_total4)
Ingresos_generales
# Out:
# Tienda
# Tienda 1    1.150880e+09
# Tienda 2    1.116344e+09
# Tienda 3    1.098020e+09
# Tienda 4    1.038376e+09
# Name: Precio, dtype: float64

# %%
import matplotlib.ticker as mticker

plt.figure(figsize=(10, 6))
ax = ingresos_ordenados.plot(kind='bar')
plt.title('Ingreso Total por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total')
plt.xticks(rotation=0)

formatter = mticker.ScalarFormatter(useOffset=False, useMathText=False)
formatter.set_scientific(False)
ax.yaxis.set_major_formatter(formatter)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
venta_categoria = tienda.groupby('Categoría del Producto')['Precio'].sum()
print(venta_categoria)
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %%
venta_categoria2 = tienda2.groupby('Categoría del Producto')['Precio'].sum()
print(venta_categoria2)
# Out:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64

# %%
venta_categoria3 = tienda3.groupby('Categoría del Producto')['Precio'].sum()
print(venta_categoria3)
# Out:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# Electrodomésticos          329237900.0
# Electrónicos               410775800.0
# Instrumentos musicales      77380900.0
# Juguetes                    19401100.0
# Libros                       9498700.0
# Muebles                    201072100.0
# Name: Precio, dtype: float64

# %%
venta_categoria4 = tienda4.groupby('Categoría del Producto')['Precio'].sum()
print(venta_categoria4)
# Out:
# Categoría del Producto
# Artículos para el hogar     15074500.0
# Deportes y diversión        33350100.0
# Electrodomésticos          283260200.0
# Electrónicos               409476100.0
# Instrumentos musicales      75102400.0
# Juguetes                    20262200.0
# Libros                       9321300.0
# Muebles                    192528900.0
# Name: Precio, dtype: float64

# %%
venta_categoria_total = (venta_categoria + venta_categoria2 + venta_categoria3 + venta_categoria4)
print(venta_categoria_total)
# Out:
# Categoría del Producto
# Artículos para el hogar    5.757980e+07
# Deportes y diversión       1.429777e+08
# Electrodomésticos          1.324751e+09
# Electrónicos               1.660576e+09
# Instrumentos musicales     3.487726e+08
# Juguetes                   7.360440e+07
# Libros                     3.769610e+07
# Muebles                    7.576610e+08
# Name: Precio, dtype: float64

# %%
venta_categoria_total = tienda_general.groupby('Categoría del Producto')['Precio'].sum()
display(venta_categoria_total)
# Out:
# Categoría del Producto
# Artículos para el hogar    5.757980e+07
# Deportes y diversión       1.429777e+08
# Electrodomésticos          1.324751e+09
# Electrónicos               1.660576e+09
# Instrumentos musicales     3.487726e+08
# Juguetes                   7.360440e+07
# Libros                     3.769610e+07
# Muebles                    7.576610e+08
# Name: Precio, dtype: float64

# %%
plt.figure(figsize=(12, 10)) # Increased figure size
venta_categoria_total.plot(kind='pie', autopct='%1.1f%%', startangle=140, labels=None, legend=True, pctdistance=0.85) # Adjusted pctdistance
plt.title('Distribución de Ventas por Categoría de Producto')
plt.ylabel('') # Remove default 'Precio' label on y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificación_tienda = tienda['Calificación'].mean()
print(calificación_tienda)
# Out:
# 3.976685036032217

# %%
calificación_tienda2 = tienda2['Calificación'].mean()
print(calificación_tienda2)
# Out:
# 4.037303942348453

# %%
calificación_tienda3 = tienda3['Calificación'].mean()
print(calificación_tienda3)
# Out:
# 4.048325561678677

# %%
calificación_tienda4 = tienda4['Calificación'].mean()
print(calificación_tienda4)
# Out:
# 3.9957591178965224

# %%
calificacion_total = tienda_general.groupby('Tienda')['Calificación'].mean()
print(calificacion_total)
# Out:
# Tienda
# Tienda 1    3.976685
# Tienda 2    4.037304
# Tienda 3    4.048326
# Tienda 4    3.995759
# Name: Calificación, dtype: float64

# %%
plt.figure(figsize=(8, 5))
calificacion_total.plot(kind='bar')
plt.title('Calificación Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Calificación Promedio')
plt.xticks(rotation=0)
plt.ylim(0, 5) # Assuming ratings are on a scale of 1-5
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
venta_categoria_ordenada = venta_categoria.sort_values(ascending=False)
venta_categoria_ordenada
# Out:
# Categoría del Producto
# Electrónicos               429493500.0
# Electrodomésticos          363685200.0
# Muebles                    187633700.0
# Instrumentos musicales      91299000.0
# Deportes y diversión        39290000.0
# Juguetes                    17995700.0
# Artículos para el hogar     12698400.0
# Libros                       8784900.0
# Name: Precio, dtype: float64

# %%
venta_categoria_ordenada2 = venta_categoria2.sort_values(ascending=False)
venta_categoria_ordenada2
# Out:
# Categoría del Producto
# Electrónicos               410831100.0
# Electrodomésticos          348567800.0
# Muebles                    176426300.0
# Instrumentos musicales     104990300.0
# Deportes y diversión        34744500.0
# Juguetes                    15945400.0
# Artículos para el hogar     14746900.0
# Libros                      10091200.0
# Name: Precio, dtype: float64

# %%
venta_categoria_ordenada3 = venta_categoria3.sort_values(ascending=False)
venta_categoria_ordenada3
# Out:
# Categoría del Producto
# Electrónicos               410775800.0
# Electrodomésticos          329237900.0
# Muebles                    201072100.0
# Instrumentos musicales      77380900.0
# Deportes y diversión        35593100.0
# Juguetes                    19401100.0
# Artículos para el hogar     15060000.0
# Libros                       9498700.0
# Name: Precio, dtype: float64

# %%
venta_categoria_ordenada4 = venta_categoria4.sort_values(ascending=False)
venta_categoria_ordenada4
# Out:
# Categoría del Producto
# Electrónicos               409476100.0
# Electrodomésticos          283260200.0
# Muebles                    192528900.0
# Instrumentos musicales      75102400.0
# Deportes y diversión        33350100.0
# Juguetes                    20262200.0
# Artículos para el hogar     15074500.0
# Libros                       9321300.0
# Name: Precio, dtype: float64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = tienda['Costo de envío'].mean()
print(f"El costo promedio de envio de la tienda es de : $ {envio_promedio:.2f}")
# Out:
# El costo promedio de envio de la tienda es de : $ 26018.61

# %%
envio_promedio2 = tienda2['Costo de envío'].mean()
print(f"El costo promediode envio de la tienda es de : $ {envio_promedio2:.2f}")
# Out:
# El costo promediode envio de la tienda es de : $ 25216.24

# %%
envio_promedio3 = tienda3['Costo de envío'].mean()
print(f"El costo promedio de envio de la tienda es de : $ {envio_promedio3:.2f}")
# Out:
# El costo promedio de envio de la tienda es de : $ 24805.68

# %%
envio_promedio4 = tienda4['Costo de envío'].mean()
print(f"El costo promedio de envio de la tienda es de : $ {envio_promedio4:.2f}")
# Out:
# El costo promedio de envio de la tienda es de : $ 23459.46

# %% [markdown]
# #**Informe**

# %% [markdown]
# De acuerdo a los datos que soltaron las tablas de informacion es posible analizar que entre las 4 tiendas que se encuentran activas la que mas se acerca a un balance entre todos los componentes es la **TIENDA 1**. Sin embargo a la Tienda 4 es la que se deberia de vender, ya que cuenta con menores ingresos y si calificacion mas baja junto con su menor volumen de ventas.

# %% [markdown]
# **Reasoning**:
# Determine the store with the highest total income and print the result.

# %%
# Out:
# La tienda con el mayor ingreso total es: Tienda 1
# El ingreso total de Tienda 1 es: $1,150,880,400.00
